# %% [markdown]
# ### Manipulação de dados para regressão linear
#
# **Métodos das velocidades indexadas**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook
import statsmodels.api as sm

# %%
df =  input(pd.read_excel('vel_index_2.xlsx'))
df.head()
# Out:
#    Unnamed: 0       data   horario  duração    vazão    area  cota  vel_med  \
# 0         NaN 2015-11-19  13:53:30       196  1374.3  1446.5  1.29      2.0
# 1         NaN 2016-10-06  08:34:04       237  1117.2  1422.1  1.17      0.9
# 2         NaN 2016-02-12  08:21:07       260   586.5  1310.7  0.78      3.7
# 3         NaN 2016-02-12  10:19:24       267   624.8  1312.8  0.79      3.7
# 4         NaN 2016-02-12  13:24:36       256   562.7  1344.4  0.81      3.7
#
#   direcao
# 0      se
# 1      ne
# 2      ne
# 3      ne
# 4      ne

# %%
cota = df['cota']
area = df['area']

# %%
plt.figure()
plt.suptitle('Cota x Área')

plt.plot(cota, area, 'ro')
plt.ylabel('Área[m²]')
plt.xlabel('Cota[m]')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
