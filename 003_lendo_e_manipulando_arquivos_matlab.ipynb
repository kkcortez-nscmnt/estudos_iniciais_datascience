# %% [markdown]
# ## Lendo Arquivos .mat

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.io as sio
import pandas as pd

# Carregando arquivos .mat
file_mat = 't4.mat'
file_dict = sio.loadmat(file_mat)
#Qtotal = file_dict['Summary']['Total_Q']
Amolhada = file_dict['Summary']['Area']
#rint(type(Qtotal))
#Qtotal.ndim
Amolhada[0][0]
# Out:
# array([[1333.5736084]])
